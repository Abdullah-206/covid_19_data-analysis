# %%
import pandas as pd

# %%
covid_19 = pd.read_csv("Downloads\covid_19_dataset.csv")

# %%
covid_19
# Out:
#          Date     State       Region  Confirmed  Deaths  Recovered
# 0    29-03-20       NaN  Afghanistan        120       4          2
# 1    29-03-20       NaN      Albania        212      10         33
# 2    29-03-20       NaN      Algeria        511      31         31
# 3    29-03-20       NaN      Andorra        334       6          1
# 4    29-03-20       NaN       Angola          7       2          0
# ..        ...       ...          ...        ...     ...        ...
# 594  31-03-20  Shandong        China        774       7        753
# 595  31-03-20  Shanghai        China        509       5        341
# 596  31-03-20    Shanxi        China        136       0        133
# 597  31-03-20   Sichuan        China        550       3        536
# 598  31-03-20   Tianjin        China        174       3        135
#
# [599 rows x 6 columns]

# %%
covid_19.shape
# Out:
# (599, 6)

# %%
covid_19.count()
# Out:
# Date         599
# State        203
# Region       599
# Confirmed    599
# Deaths       599
# Recovered    599
# dtype: int64

# %%
covid_19.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 594  False  False   False      False   False      False
# 595  False  False   False      False   False      False
# 596  False  False   False      False   False      False
# 597  False  False   False      False   False      False
# 598  False  False   False      False   False      False
#
# [599 rows x 6 columns]

# %%
covid_19.isnull().sum()
# Out:
# Date           0
# State        396
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
# For Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid_19.isnull())
plt.show()

# %%
covid_19.head(10)
# Out:
#        Date                         State               Region  Confirmed  \
# 0  29-03-20                           NaN          Afghanistan        120
# 1  29-03-20                           NaN              Albania        212
# 2  29-03-20                           NaN              Algeria        511
# 3  29-03-20                           NaN              Andorra        334
# 4  29-03-20                           NaN               Angola          7
# 5  29-03-20                           NaN  Antigua and Barbuda          7
# 6  29-03-20                           NaN            Argentina        745
# 7  29-03-20                           NaN              Armenia        424
# 8  29-03-20  Australian Capital Territory            Australia         77
# 9  29-03-20               New South Wales            Australia       1791
#
#    Deaths  Recovered
# 0       4          2
# 1      10         33
# 2      31         31
# 3       6          1
# 4       2          0
# 5       0          0
# 6      19         72
# 7       3         30
# 8       0          2
# 9       8          4

# %%
covid_19.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan               464      12          9
# Albania                   678      36        129
# Algeria                  1811     110        114
# Andorra                  1080      26         21
# Angola                     21       6          1
# ...                       ...     ...        ...
# West Bank and Gaza        225       2         36
# Western Sahara              0       0          0
# Yemen                       0       0          0
# Zambia                     64       0          0
# Zimbabwe                   14       2          0
#
# [187 rows x 3 columns]

# %%
covid_19.groupby('Region').sum().head(40)
# Out:
#                           Confirmed  Deaths  Recovered
# Region
# Afghanistan                     464      12          9
# Albania                         678      36        129
# Algeria                        1811     110        114
# Andorra                        1080      26         21
# Angola                           21       6          1
# Antigua and Barbuda              21       0          0
# Argentina                      2619      69        540
# Armenia                        1438       9         90
# Australia                     12904      51        859
# Austria                       28586     322       2210
# Azerbaijan                      780      13         67
# Bahamas                          39       0          3
# Bahrain                        1581      12        846
# Bangladesh                      148      15         59
# Barbados                        100       0          0
# Belarus                         398       1        111
# Belgium                       35510    1649       4582
# Belize                            5       0          0
# Benin                            21       0          1
# Bhutan                           12       0          0
# Bolivia                         285      11          0
# Bosnia and Herzegovina         1111      29         42
# Botswana                          3       0          0
# Brazil                        14552     496        253
# Brunei                          382       3        117
# Bulgaria                       1104      24         48
# Burkina Faso                    729      38         86
# Burma                            24       0          0
# Burundi                           0       0          0
# Cabo Verde                       18       3          0
# Cambodia                        319       0         65
# Cameroon                        471      18         15
# Canada                        22160     242          0
# Central African Republic          9       0          0
# Chad                             15       0          0
# Chile                          7644      27        387
# China                        245083    9915     221556
# Colombia                       1500      22         25
# Comoros                           0       0          0
# Congo (Brazzaville)              38       0          0

# %%
covid_19.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan            464
# Albania                678
# Algeria               1811
# Andorra               1080
# Angola                  21
#                       ...
# West Bank and Gaza     225
# Western Sahara           0
# Yemen                    0
# Zambia                  64
# Zimbabwe                14
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid_19.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
#covid_19.groupby('Region').Deaths.sum().sort_values(ascending=True).head(40)
#covid_19[covid_19.Region == 'Canada']
# Out:
# Region
# US                       303912
# China                    245083
# Italy                    199428
# Spain                    168066
# Germany                  128980
#                           ...
# Comoros                       0
# Sierra Leone                  0
# Sao Tome and Principe         0
# Burundi                       0
# Lesotho                       0
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid_19.groupby('Region')['Confirmed','Deaths'].sum()
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_9600\2091745899.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid_19.groupby('Region')['Confirmed','Deaths'].sum()
#                     Confirmed  Deaths
# Region
# Afghanistan               464      12
# Albania                   678      36
# Algeria                  1811     110
# Andorra                  1080      26
# Angola                     21       6
# ...                       ...     ...
# West Bank and Gaza        225       2
# Western Sahara              0       0
# Yemen                       0       0
# Zambia                     64       0
# Zimbabwe                   14       2
#
# [187 rows x 2 columns]

# %%
covid_19.head(5)
# Out:
#        Date State       Region  Confirmed  Deaths  Recovered
# 0  29-03-20   NaN  Afghanistan        120       4          2
# 1  29-03-20   NaN      Albania        212      10         33
# 2  29-03-20   NaN      Algeria        511      31         31
# 3  29-03-20   NaN      Andorra        334       6          1
# 4  29-03-20   NaN       Angola          7       2          0

# %%
covid_19[~(covid_19.Confirmed)<10]
# Out:
#          Date     State       Region  Confirmed  Deaths  Recovered
# 0    29-03-20       NaN  Afghanistan        120       4          2
# 1    29-03-20       NaN      Albania        212      10         33
# 2    29-03-20       NaN      Algeria        511      31         31
# 3    29-03-20       NaN      Andorra        334       6          1
# 4    29-03-20       NaN       Angola          7       2          0
# ..        ...       ...          ...        ...     ...        ...
# 594  31-03-20  Shandong        China        774       7        753
# 595  31-03-20  Shanghai        China        509       5        341
# 596  31-03-20    Shanxi        China        136       0        133
# 597  31-03-20   Sichuan        China        550       3        536
# 598  31-03-20   Tianjin        China        174       3        135
#
# [599 rows x 6 columns]

# %%
covid_19
# Out:
#          Date     State       Region  Confirmed  Deaths  Recovered
# 0    29-03-20       NaN  Afghanistan        120       4          2
# 1    29-03-20       NaN      Albania        212      10         33
# 2    29-03-20       NaN      Algeria        511      31         31
# 3    29-03-20       NaN      Andorra        334       6          1
# 4    29-03-20       NaN       Angola          7       2          0
# ..        ...       ...          ...        ...     ...        ...
# 594  31-03-20  Shandong        China        774       7        753
# 595  31-03-20  Shanghai        China        509       5        341
# 596  31-03-20    Shanxi        China        136       0        133
# 597  31-03-20   Sichuan        China        550       3        536
# 598  31-03-20   Tianjin        China        174       3        135
#
# [599 rows x 6 columns]

# %%
covid_19=covid_19[~(covid_19.Confirmed)<10]

# %%
covid_19
# Out:
#          Date     State       Region  Confirmed  Deaths  Recovered
# 0    29-03-20       NaN  Afghanistan        120       4          2
# 1    29-03-20       NaN      Albania        212      10         33
# 2    29-03-20       NaN      Algeria        511      31         31
# 3    29-03-20       NaN      Andorra        334       6          1
# 4    29-03-20       NaN       Angola          7       2          0
# ..        ...       ...          ...        ...     ...        ...
# 594  31-03-20  Shandong        China        774       7        753
# 595  31-03-20  Shanghai        China        509       5        341
# 596  31-03-20    Shanxi        China        136       0        133
# 597  31-03-20   Sichuan        China        550       3        536
# 598  31-03-20   Tianjin        China        174       3        135
#
# [599 rows x 6 columns]
